# %%
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# plotting a boxplot of Age to identify outliers

# %%
plt.boxplot(df['Age'].dropna())  
plt.title("Box Plot of Age")
plt.ylabel("Age") 
plt.show()

# %%
median_age = df['Age'].median()
df['Age'] = df['Age'].fillna(median_age)

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
plt.hist(df['Age'], edgecolor='black')

plt.title("Scores vs. Frequency")
plt.xlabel("Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Fare"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
plt.boxplot(df['Fare'])  
plt.title("Box Plot of Fare")
plt.ylabel("Fare") 

plt.show()

# %%
df.tail(20)
# Out:
#      PassengerId  Survived  Pclass
# 871          872         1       1  \
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1  \
# ...

# %%
df['Family_size']=df['Parch']+ df['SibSp'] + 1
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=["Cabin","SibSp", "Parch"], inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
df.drop(columns=["PassengerId"], inplace=True)
df
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age            Ticket     Fare Embarked  Family_size
# ...

# %%
# Extract titles from passenger names to create some sort of new column which we think could influence survival
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
df
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age            Ticket     Fare Embarked  Family_size Title
# ...

# %%
df.drop(columns=["Name"], inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age            Ticket     Fare Embarked
# 0           0       3    male  22.0         A/5 21171   7.2500        S  \
# 1           1       1  female  38.0          PC 17599  71.2833        C
# 2           1       3  female  26.0  STON/O2. 3101282   7.9250        S
# 3           1       1  female  35.0            113803  53.1000        S
# 4           0       3    male  35.0            373450   8.0500        S
# ..        ...     ...     ...   ...               ...      ...      ...
# 886         0       2    male  27.0            211536  13.0000        S
# 887         1       1  female  19.0            112053  30.0000        S
# 888         0       3  female  28.0        W./C. 6607  23.4500        S
# 889         1       1    male  26.0            111369  30.0000        C
# 890         0       3    male  32.0            370376   7.7500        Q
#
#      Family_size Title
# 0              2    Mr
# 1              2   Mrs
# 2              1  Miss
# ...

# %%
# Create age groups
bins = [0, 18, 30, 50, float('inf')]
labels = ['Child', 'Young Adult', 'Adult', 'Senior']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
df
# Out:
#      Survived  Pclass     Sex   Age            Ticket     Fare Embarked
# 0           0       3    male  22.0         A/5 21171   7.2500        S  \
# 1           1       1  female  38.0          PC 17599  71.2833        C
# 2           1       3  female  26.0  STON/O2. 3101282   7.9250        S
# 3           1       1  female  35.0            113803  53.1000        S
# 4           0       3    male  35.0            373450   8.0500        S
# ..        ...     ...     ...   ...               ...      ...      ...
# 886         0       2    male  27.0            211536  13.0000        S
# 887         1       1  female  19.0            112053  30.0000        S
# 888         0       3  female  28.0        W./C. 6607  23.4500        S
# 889         1       1    male  26.0            111369  30.0000        C
# 890         0       3    male  32.0            370376   7.7500        Q
#
#      Family_size Title     AgeGroup
# 0              2    Mr  Young Adult
# ...

# %%
# Group data by age group and calculate survival statistics
age_group_survival = df.groupby('AgeGroup')['Survived'].mean()

# Create a bar chart
plt.bar(age_group_survival.index, age_group_survival.values)
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Age Group')
plt.show()

# %%
# Calculate survival rate by passenger class
survival_rate_by_class = df.groupby('Pclass')['Survived'].mean()

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(survival_rate_by_class.index, survival_rate_by_class.values * 100, color='red')

# Add labels and title
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate (%)')
plt.title('Survival Rate by Passenger Class')

# Customize x-axis ticks and labels
plt.xticks(survival_rate_by_class.index, labels=['1st Class', '2nd Class', '3rd Class'])

# Display the plot
plt.show()

# %%
import seaborn as sns
corr_df = df[['Age', 'Family_size','Survived','Fare']].copy()

corr_matrix = corr_df.corr()

#using a heatmap to visualize
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
plt.violinplot(df['Fare'], vert=False, widths=0.7, showmeans=True, showextrema=True, showmedians=True)

# Add labels and title
plt.xlabel('Fare')
plt.ylabel('Distribution')
plt.title('Distribution of Fares Paid by Passengers')
# Out:
# Text(0.5, 1.0, 'Distribution of Fares Paid by Passengers')

# %%
# Calculate survival rates per title and pclass
title_survival_rates = (
    df.groupby(["Sex", "Title"])["Survived"]
    .mean()
    .unstack()
    .fillna(0)  # Fill missing values with 0 for consistent display
)

# Create the bar chart
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
title_survival_rates.plot(kind="bar")

# Customize chart elements
plt.xlabel("Gender")
plt.ylabel("Survival Rate")
plt.title("Survival Rates by Passenger Title and Sex")
plt.legend()
plt.xticks(rotation=0)  # Adjust x-axis label rotation as needed
plt.grid(True)

# Visual cues for survival rates
plt.axhline(y=0.5, color="gray", linestyle="--")  # Add a dashed line at 50% survival rate
plt.ylim(0, 1)  # Set y-axis limits to 0-1 for survival rates

plt.show()
